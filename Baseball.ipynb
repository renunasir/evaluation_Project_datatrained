# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings
warnings.filterwarnings('ignore')

# %%
baseball = pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')

# %%
baseball.head()

#Wins, Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases,
#Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
baseball.shape
# Out:
# (30, 17)

# %%
baseball.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
baseball.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# Checking Null Values in the DataFrame

# %%
#Checking Null values
baseball.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#Using heatmap to check Null Values
import seaborn as sns
sns.heatmap(baseball.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# We have seen null values using heatmap. So,  no null values are present in the data.

# %% [markdown]
# # Visualization of Data

# %%
#Univariate Analysis
plt.hist(baseball['E'],bins=10,color='green')
# Out:
# (array([5., 1., 9., 6., 2., 1., 0., 1., 3., 2.]),
#  array([ 75. ,  80.1,  85.2,  90.3,  95.4, 100.5, 105.6, 110.7, 115.8,
#         120.9, 126. ]),
#  <BarContainer object of 10 artists>)

# %%
#Univariate Analysis
baseball['SHO'].plot.bar(color='green')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The maximum number of shutouts are at values 17 & 25

# %%
#Univariate Analysis
sns.violinplot(x='AB',data=baseball,color='green')
# Out:
# <AxesSubplot:xlabel='AB'>

# %% [markdown]
# The maximum data in column At Bats are between values 5450 and 5550

# %%
#Univariate Analysis
sns.distplot(baseball['RA'],bins=20,color='green')
# Out:
# <AxesSubplot:xlabel='RA', ylabel='Density'>

# %% [markdown]
# The maximum number of Runs Allowed lies between the range 590 to 770 and the data is normally distributed.

# %%
#Bivariate Analysis
plt.scatter(baseball["E"],baseball["W"],alpha=0.8,color='green')
plt.title("E vs W")
plt.show()

# %% [markdown]
# As the number of Errors increased, the number of Wins decreased. Hence they are negatively correlated to each other.

# %%
#Bivariate Analysis
plt.scatter(baseball["3B"],baseball["W"],alpha=0.5,color='green')
plt.title("ERA vs W")
plt.show()

# %%
sns.pairplot(baseball)

# %% [markdown]
# Variables RA, ER, 3B and ERA are in negative linear correlation to the Wins. Variables SV, SHO, BB, HR and R are in positive correlation to the Wins. This is the observation from the above graph. For better understanding of correlated variables, Let's understand data and use heatmap to see correlations.

# %% [markdown]
# # Describe Data

# %%
baseball.shape
# Out:
# (30, 17)

# %%
baseball.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# These are the different variables present in our dataset.

# %%
#Getting information of our data
baseball.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Describing our data
baseball.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
#Describing data using heatmap
import matplotlib.pyplot as plt
plt.figure(figsize=(23,8))
sns.heatmap(baseball.describe(),annot=True,linewidths=0.1,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
 we can see that from the above description data of most of the columns are broadly scattered i.e. the std of most columns are quite high.
There are no huge variations in the min and max values of each column which means that it has a less chance of having outliers.
Every column has a differnt range of values which shows huge variations in the values of a dataset.
# Out:
#   Input In [171]
#     we can see that from the above description data of most of the columns are broadly scattered i.e. the std of most columns are quite high.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Correlation of Columns with the Target Variable

# %%
baseball.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
#Describing data using heatmap
plt.figure(figsize=(22,7))
sns.heatmap(baseball.corr(),cmap='summer',annot=True,linewidths=0.1,linecolor='black',fmt='0.1f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From above heatmap, we can see that output is in good correlation with all the inputs, so will not drop any column.

# %% [markdown]
# The most positively correlated columns to the number of Wins are Saves(SV), Shutouts(SHO), Walks(BB), Runs(R) and Doubles(2B)
# The most negatively correlated columns to the number of WIns are Runs Allowed(RA),Earned Runs(ER)and Earned Run Average(ERA)

# %%
sns.heatmap(baseball.corr()[['W']].sort_values(by='W',ascending= False ), vmin=-1,vmax=1,annot= True,color='blue')
# Out:
# <AxesSubplot:>

# %% [raw]
# Heatmap shows good correlation between Wins and SV
# Moderate correlation between W and SHO
# Negative correlation of W with - ER, RA, ERA

# %% [markdown]
# # Checking Skewness

# %%
#Checking Skewness 
baseball.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Threshold +/-0.5 as the range for skewness, we can see that there is not much skewness in our data. Hardly some skewness can be seen in columns H, R, CG, SH0, SV & E. Let's try plotting skewness in columns using density graph

# %%
#Visualizing skewness on density graph
# Multi variate analysis
baseball.plot(kind='density',subplots=True,layout=(4,6),legend=False,sharex=False,figsize=(40,30))
plt.show()

# %% [markdown]
# # Checking Outliers

# %%
#Checking datatype of data in each column 
baseball.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
baseball['R'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ony one outlier value can be found

# %%
baseball['E'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Only few outliers can be detected

# %%
baseball['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outlier can be detected

# %%
#Multivariate analysis to check outliers
baseball.plot(kind='box',subplots=True,layout=(4,6),figsize=(20,30))
# Out:
# W          AxesSubplot(0.125,0.71587;0.110714x0.16413)
# R       AxesSubplot(0.257857,0.71587;0.110714x0.16413)
# AB      AxesSubplot(0.390714,0.71587;0.110714x0.16413)
# H       AxesSubplot(0.523571,0.71587;0.110714x0.16413)
# 2B      AxesSubplot(0.656429,0.71587;0.110714x0.16413)
# 3B      AxesSubplot(0.789286,0.71587;0.110714x0.16413)
# HR        AxesSubplot(0.125,0.518913;0.110714x0.16413)
# BB     AxesSubplot(0.257857,0.518913;0.110714x0.16413)
# SO     AxesSubplot(0.390714,0.518913;0.110714x0.16413)
# SB     AxesSubplot(0.523571,0.518913;0.110714x0.16413)
# RA     AxesSubplot(0.656429,0.518913;0.110714x0.16413)
# ER     AxesSubplot(0.789286,0.518913;0.110714x0.16413)
# ERA       AxesSubplot(0.125,0.321957;0.110714x0.16413)
# CG     AxesSubplot(0.257857,0.321957;0.110714x0.16413)
# SHO    AxesSubplot(0.390714,0.321957;0.110714x0.16413)
# SV     AxesSubplot(0.523571,0.321957;0.110714x0.16413)
# E      AxesSubplot(0.656429,0.321957;0.110714x0.16413)
# dtype: object

# %% [markdown]
# There are very minimal number of outliers present which can be of huge importance to our data. Hence, we don't resolve them.

# %% [markdown]
# # Removing Outliers using Zscore

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(baseball))
z
# Out:
#            W         R        AB         H        2B        3B        HR  \
# 0   1.365409  0.619078  0.847731  1.663685  1.420173  1.041193  0.787299
# 1   0.197838  0.134432  0.711094  0.970681  0.127403  1.235809  0.243967
# 2   0.003243  0.332906  1.115233  0.151891  1.588795  0.223808  0.723377
# 3   0.483244  1.146419  0.241522  0.401088  0.828122  0.418423  0.883181
# 4   0.677839  0.013270  1.280738  1.984081  0.801892  1.722347  0.403770
# 5   1.170814  3.509647  0.104884  1.361089  1.869832  1.391501  2.185047
# 6   0.587028  1.311430  0.732263  0.116292  0.153633  1.196885  1.545833
# 7   0.003243  0.428681  0.451289  0.596886  1.615025  1.099578  1.705636
# 8   0.094054  0.765626  0.451289  0.365489  0.183611  0.068115  0.107601
# 9   0.288649  1.034489  1.785913  1.628086  1.082929  0.165423  0.084163
# 10  0.684326  1.086415  0.076017  0.275303  0.239818  0.068115  0.267405
# 11  0.489731  0.705622  0.826562  0.721484  0.183611  0.515731  2.121125
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
baseball_new=baseball[(z<3).all(axis=1)]

# %%
baseball_new.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
baseball.shape
# Out:
# (30, 17)

# %%
baseball_new.shape
# Out:
# (29, 17)

# %%
loss_percentage=(30-29)/30*100
print(loss_percentage)
# Out:
# 3.3333333333333335

# %%
baseball=baseball_new

# %%
baseball.shape
# Out:
# (29, 17)

# %%
x=baseball.iloc[:,1:]
x.head(4)
# Out:
#      R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  SV  \
# 0  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8  56
# 1  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12  45
# 2  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10  38
# 3  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9  37
#
#      E
# 0   88
# 1   86
# 2   79
# 3  101

# %%
y=baseball.iloc[:,-17]
y.head(4)
# Out:
# 0    95
# 1    83
# 2    81
# 3    76
# Name: W, dtype: int64

# %% [markdown]
# # Removing Skewness

# %%
baseball.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# We will use power transform method to remove skewness from the data.

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052224e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800488e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213881e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %%
baseball['R'].plot.hist(color='green')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
baseball['H'].plot.hist(color='green')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
baseball['SO'].plot.hist(color='green')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
baseball['CG'].plot.hist(color='green')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Scaling of the data

# %%
# StandardScaler for scaling of data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 9.62543504e-01,  0.00000000e+00,  0.00000000e+00,
#          1.68518793e+00,  1.00615029e+00, -7.41927000e-01,
#         -1.60519802e+00, -2.55061247e+00,  9.36131648e-01,
#         -6.60978697e-01, -5.08052224e-01, -5.09292146e-01,
#         -3.07098204e-01, -7.87002186e-01,  1.53275292e+00,
#         -3.48265262e-01],
#        [ 2.98863300e-01,  0.00000000e+00,  0.00000000e+00,
#          1.38197902e-01,  1.18522654e+00, -1.09958425e-01,
#         -4.62095966e-01,  9.36832915e-02, -5.16377335e-01,
#          1.60225829e-01,  2.35800488e-01,  2.41440214e-01,
#         -3.07098204e-01,  2.36736538e-01,  3.12020186e-01,
#         -5.40819806e-01],
#        [-3.12105130e-01,  0.00000000e+00,  0.00000000e+00,
#          1.90738550e+00, -2.28819392e-01, -6.64354121e-01,
#          1.23209786e+00, -9.35611465e-01,  2.25038365e-01,
#         -6.74967476e-01, -7.52213881e-01, -6.42097599e-01,
#          2.01131531e+00, -2.52844176e-01, -6.64136739e-01,
#         -1.32612477e+00],
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=4)

# %%
x_train.shape
# Out:
# (20, 16)

# %%
x_test.shape
# Out:
# (9, 16)

# %%
y_train.shape
# Out:
# (20,)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)
# Out:
# 0.9696002773880019

# %% [markdown]
# Here in linear regression score is coming out as 96%, we will use other models further to check the predicted score value.

# %%
pred=lr.predict(x_test)
print('Predicted result price:',pred)
print('actual price',y_test)
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Predicted result price: [ 78.76814147  56.24598347 102.02725288  97.56885559  83.17756406
#   82.72653919  72.16026244  61.30069684  87.2290278 ]
# actual price 12    85
# 22    71
# 28    74
# 16    98
# 21    83
# 25    92
# 18    68
# 26    84
# 20    90
# Name: W, dtype: int64
# error:
# Mean absolute error: 9.836203890332603
# Mean squared error: 185.38921029751884
# Root Mean Squared Error: 13.615770646478989

# %%
print(r2_score(y_test,pred))
# Out:
# -1.0610109846416451

# %%
from sklearn.linear_model import Lasso,Ridge
from sklearn.linear_model import ElasticNet

# %%
ls=Lasso(alpha=0.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
# Out:
# 0.9648456385148351

# %%
predls=ls.predict(x_test)
print('Predicted result price:',predls)
print('actual price',y_test)
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predls))
print('Mean squared error:',mean_squared_error(y_test,predls))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predls)))
# Out:
# Predicted result price: [78.82368511 68.38116916 78.64743062 95.24221254 87.10366201 87.14497958
#  71.59833431 86.05061365 86.12150634]
# actual price 12    85
# 22    71
# 28    74
# 16    98
# 21    83
# 25    92
# 18    68
# 26    84
# 20    90
# Name: W, dtype: int64
# error:
# Mean absolute error: 3.8540542068910546
# Mean squared error: 16.312905337538297
# Root Mean Squared Error: 4.038923784566663

# %%
print(r2_score(y_test,predls))
# Out:
# 0.8186459878752949

# %%
rd=Ridge(alpha=0.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
# Out:
# 0.9695446896075324

# %%
predrd=rd.predict(x_test)
print('Predicted result price:',predrd)
print('actual price',y_test)
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predrd))
print('Mean squared error:',mean_squared_error(y_test,predrd))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predrd)))
# Out:
# Predicted result price: [78.76792541 57.54837313 99.51141348 97.33734598 83.59552331 83.19412102
#  72.0940686  63.96689902 87.11533557]
# actual price 12    85
# 22    71
# 28    74
# 16    98
# 21    83
# 25    92
# 18    68
# 26    84
# 20    90
# Name: W, dtype: int64
# error:
# Mean absolute error: 9.141222805972502
# Mean squared error: 152.81803569162756
# Root Mean Squared Error: 12.361959217358208

# %%
print(r2_score(y_test,predrd))
# Out:
# -0.6989103611064824

# %% [markdown]
# In ridge r2 score is 0.69, which is lesser than lasso i.e is 0.81

# %%
from sklearn.linear_model import ElasticNet

# %%
enr=ElasticNet(alpha=0.0001)
enr.fit(x_train,y_train)
enr.score(x_train,y_train)
# Out:
# 0.9648174836269281

# %%
predenr=enr.predict(x_test)
print('Predicted result price:',predenr)
print('actual price',y_test)
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predenr))
print('Mean squared error:',mean_squared_error(y_test,predenr))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predenr)))
# Out:
# Predicted result price: [78.82498826 68.41461794 78.57655062 95.23171142 87.1142196  87.15996032
#  71.59759359 86.12182043 86.11979036]
# actual price 12    85
# 22    71
# 28    74
# 16    98
# 21    83
# 25    92
# 18    68
# 26    84
# 20    90
# Name: W, dtype: int64
# error:
# Mean absolute error: 3.851012883858448
# Mean squared error: 16.252980351706558
# Root Mean Squared Error: 4.031498524333918

# %%
print(r2_score(y_test,predenr))
# Out:
# 0.8193121865923372

# %% [markdown]
# In elasticnet r2 score is 0.81, which is lesser than lr i.e is 1.69.

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lr,x,y,cv=8)
print(score)
print (score.mean())
print (score.std())
# Out:
# [ 0.90319434 -0.72600004 -0.05216636  0.69988045  0.96422777  0.26869168
#   0.86207588 -1.23309368]
# 0.21085125401385918
# 0.7701744366755617

# %%
score=cross_val_score(ls,x,y,cv=8)
print(score)
print (score.mean())
print (score.std())
# Out:
# [ 0.92034908 -0.711604    0.00918858  0.69896994  0.96445947  0.29676839
#   0.86732165 -1.2590951 ]
# 0.22329474919207917
# 0.7745161877955339

# %%
score=cross_val_score(rd,x,y,cv=8)
print(score)
print (score.mean())
print (score.std())
# Out:
# [ 0.90324694 -0.72540315 -0.05138884  0.70001197  0.96421686  0.27017958
#   0.86214186 -1.22670657]
# 0.21203733062526534
# 0.7685906300994086

# %% [markdown]
# # Hypermeter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
alphavalue={'alpha':[1,0.1,0.01,0.001,0.0001,0]}
modelrd=Ridge()
modells=Lasso()

# %%
grid= GridSearchCV(estimator=modelrd,param_grid=alphavalue)
grid.fit(x,y)
print(grid)
print(grid.best_score_)
print(grid.best_estimator_.alpha)
print(grid.best_params_)
# Out:
# GridSearchCV(estimator=Ridge(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0]})
# 0.4709229601723763
# 0.1
# {'alpha': 0.1}

# %% [raw]
# By using gridsearchCV, alpha value 1 is the best value for Ridge. So, we will predict the result using it

# %%
grid1= GridSearchCV(estimator=modells,param_grid=alphavalue)
grid1.fit(x,y)
print(grid1)
print(grid1.best_score_)
print(grid1.best_estimator_.alpha)
print(grid1.best_params_)
# Out:
# GridSearchCV(estimator=Lasso(),
#              param_grid={'alpha': [1, 0.1, 0.01, 0.001, 0.0001, 0]})
# 0.5100687480812115
# 1
# {'alpha': 1}

# %%
ls1=Lasso(alpha=1)
ls1.fit(x_train,y_train)
ls1.score(x_train,y_train)
# Out:
# 0.8877427720363401

# %%
predls1=ls1.predict(x_test)
print('Predicted result price:',predls1)
print('actual price',y_test)
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predls1))
print('Mean squared error:',mean_squared_error(y_test,predls1))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predls1)))
# Out:
# Predicted result price: [80.85935317 72.27623098 76.17109486 93.25210051 85.74580265 87.68491045
#  73.99925228 83.85650262 89.21210801]
# actual price 12    85
# 22    71
# 28    74
# 16    98
# 21    83
# 25    92
# 18    68
# 26    84
# 20    90
# Name: W, dtype: int64
# error:
# Mean absolute error: 2.9252673352474483
# Mean squared error: 12.091305263983873
# Root Mean Squared Error: 3.4772554211596067

# %%
print(r2_score(y_test,predls1))
# Out:
# 0.8655784070295507

# %% [markdown]
# r2 score of Lasso remains the same after using alpha=1 also, so we will use any of the lasso model.

# %%
rd1=Ridge(alpha=1)
rd1.fit(x_train,y_train)
rd1.score(x_train,y_train)
# Out:
# 0.9557933687279061

# %%
predrd1=rd1.predict(x_test)
print('Predicted result price:',predrd1)
print('actual price',y_test)
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predrd1))
print('Mean squared error:',mean_squared_error(y_test,predrd1))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predrd1)))
# Out:
# Predicted result price: [79.46300235 68.13414214 74.50938111 93.6090259  86.81690503 88.55299704
#  72.27780958 87.48610967 87.91221645]
# actual price 12    85
# 22    71
# 28    74
# 16    98
# 21    83
# 25    92
# 18    68
# 26    84
# 20    90
# Name: W, dtype: int64
# error:
# Mean absolute error: 3.3798690575669514
# Mean squared error: 13.297072884910568
# Root Mean Squared Error: 3.646515169982235

# %%
print(r2_score(y_test,predrd1))
# Out:
# 0.8521736338625094

# %% [markdown]
# r2 score of ridge remains the same after using alpha=1 also.

# %% [markdown]
# As from the above models, we can see that r2 score of lasso model is best. i.e 87. So, we will use this model for prediction and save it.
